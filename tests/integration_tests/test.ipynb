# %%
from problab.random_variables.new_base import *

X = RandomVariable(
    CategoricalDistribution(
        categories=[1, 2, 3],
        probabilities=[0.2, 0.3, 0.5],
    )
)

print(X.sample(10))
print((X + 5).sample(10))
# Out:
# [2 3 3 3 1 3 3 3 2 3]
# [7 8 6 8 7 8 6 8 7 8]
